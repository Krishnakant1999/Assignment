# %% [markdown]
# Q.1.Explain why we have to use the Exception class while creating a Custom Exception.

# %% [markdown]
# By creating custom exceptions that inherit from exception class we can define specific exceptional conditions that are revelent to our applications.This allows us catch and handle different types of exceptions seperately.

# %% [markdown]
# Q2. Write a python program to print Python Exception Hierarchy.

# %% [markdown]
# Python Exception Hierarchy, starting from the BaseException class and including all built-in exception classes.

# %%
# import inspect module
import inspect

# our treeClass function
def treeClass(cls, ind = 0):

    # print name of the class
    print ('-' * ind, cls.__name__)

    # iterating through subclasses
    for i in cls.__subclasses__():
        treeClass(i, ind + 3)

print("Hierarchy for Built-in exceptions is : ")

# inspect.getmro() Return a tuple
# of class cls’s base classes.

# building a tree hierarchy
inspect.getclasstree(inspect.getmro(BaseException))

# function call
treeClass(BaseException)
# Out:
# Hierarchy for Built-in exceptions is :
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# --------- MultipartConversionError
# ------ StopAsyncIteration
# ------ StopIteration
# ------ ImportError
# --------- ModuleNotFoundError
# --------- ZipImportError
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# ------------ ConnectionAbortedError
# ------------ ConnectionRefusedError
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# --------- BlockingIOError
# --------- ChildProcessError
# --------- FileExistsError
# --------- FileNotFoundError
# --------- IsADirectoryError
# --------- NotADirectoryError
# --------- InterruptedError
# ------------ InterruptedSystemCall
# --------- PermissionError
# --------- ProcessLookupError
# --------- TimeoutError
# --------- UnsupportedOperation
# --------- herror
# --------- gaierror
# --------- timeout
# --------- SSLError
# ------------ SSLCertVerificationError
# ...

# %% [markdown]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [markdown]
# The ArithmeticError class in Python is a base class for arithmetic-related exceptions.

# %%
#ZeroDivisionError
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Error: Division by zero!")
# Out:
# Error: Division by zero!

# %%
#OverflowError
import sys

try:
    result = sys.maxsize * 2
except OverflowError:
    print("Error: Numeric overflow!")

# %%
#FloatingPointError
import math

try:
    result = math.sqrt(-1)
except FloatingPointError as e:
    print("Error:", e)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6124\62334853.py in <module>
#       3
#       4 try:
# ----> 5     result = math.sqrt(-1)
#       6 except FloatingPointError as e:
#       7     print("Error:", e)
#
# ValueError: math domain error

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [markdown]
# The LookupError class in Python is a base class for exceptions related to lookup or indexing operations.

# %%
#KeyError
my_dict = {'a': 1, 'b': 2, 'c': 3}

try:
    value = my_dict['d']
except KeyError as e:
    print("Error:", e)
# Out:
# Error: 'd'

# %%
#IndexError
my_list = [1, 2, 3]

try:
    value = my_list[3]
except IndexError as e:
    print("Error:", e)
# Out:
# Error: list index out of range

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# ImportError is an exception class in Python that is raised when an imported module, package, or object cannot be found or loaded. It occurs when there is an issue with importing a module or when a required dependency is missing. The ImportError class is a base class for several specific import-related exceptions, including ModuleNotFoundError.

# %% [markdown]
# ModuleNotFoundError specifically indicates that a module or package could not be found.

# %%
# example.py

try:
    import nonexistent_module
except ImportError as e:
    print("Error:", e)
# Out:
# Error: No module named 'nonexistent_module'

# %% [markdown]
# Q6. List down some best practices for exception handling in python.

# %%
1.Use always a specific exception and not generic one
2.Print always  a proper message
3.Always try to log your error
4.Always avoid to write a multiple exception handling
5.Document all the error
6.Cleanup all the resources
